# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install keras-core --upgrade
# !pip install -q keras-nlp
# !pip install seaborn

import os
os.environ['KERAS_BACKEND'] = 'tensorflow'
# Out:
# Requirement already satisfied: keras-core in /usr/local/lib/python3.10/dist-packages (0.1.7)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras-core) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-core) (1.23.5)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras-core) (13.7.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras-core) (0.0.7)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-core) (3.9.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from keras-core) (0.1.8)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras-core) (0.1.2)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import keras_core as keras
import keras_nlp
import seaborn as sns
import matplotlib.pyplot as plt
import os

print("TensorFlow version:", tf.__version__)
print("Keras version:", keras.__version__)
print("KerasNLP version:", keras_nlp.__version__)
# Out:
# TensorFlow version: 2.15.0
# Keras version: 0.1.7
# KerasNLP version: 0.6.4

# %% [markdown]
# # Load the Keystroke Logging dataset

# %%
DATA_DIR = '/content/drive/MyDrive/DeepData/'

for dirname, _, filenames in os.walk(DATA_DIR):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/drive/MyDrive/DeepData/train_logs.csv
# /content/drive/MyDrive/DeepData/test_logs.csv
# /content/drive/MyDrive/DeepData/train_scores.csv

# %%
df_train_scores = pd.read_csv(DATA_DIR + "train_scores.csv")
df_train_scores.head()
# Out:
#          id  score
# 0  001519c8    3.5
# 1  0022f953    3.5
# 2  0042269b    6.0
# 3  0059420b    2.0
# 4  0075873a    4.0

# %%
from matplotlib import pyplot as plt
df_train_scores.plot(kind='hist', bins=20, title='score')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
f, ax = plt.subplots(figsize=(12, 4))
ax = sns.countplot(data=df_train_scores,
                   x="score")

ax.set_title("Distribution of scores")
# Out:
# Text(0.5, 1.0, 'Distribution of scores')

# %%
df_train_logs = pd.read_csv(DATA_DIR + "train_logs.csv")
df_test_logs = pd.read_csv(DATA_DIR + "test_logs.csv")


print(df_train_logs.shape)
print(df_test_logs.shape)
df_train_logs.head()
# Out:
# (8405898, 11)
# (6, 11)
#          id  event_id  down_time  up_time  action_time       activity  \
# 0  001519c8         1       4526     4557           31  Nonproduction
# 1  001519c8         2       4558     4962          404  Nonproduction
# 2  001519c8         3     106571   106571            0  Nonproduction
# 3  001519c8         4     106686   106777           91          Input
# 4  001519c8         5     107196   107323          127          Input
#
#   down_event   up_event text_change  cursor_position  word_count
# 0  Leftclick  Leftclick    NoChange                0           0
# 1  Leftclick  Leftclick    NoChange                0           0
# 2      Shift      Shift    NoChange                0           0
# 3          q          q           q                1           1
# 4          q          q           q                2           1

# %%
print('The average of the number of events per essay in the train dataset is : ' + str(df_train_logs.groupby("id").mean(numeric_only=True)["event_id"].mean().round(0)))
print('The average of the number of events per essay in the test dataset is : ' + str(df_test_logs.groupby("id").mean(numeric_only=True)["event_id"].mean().round(0)))

fig = plt.figure(figsize=(30,18))
plot = sns.displot(data=df_train_logs[["id","event_id"]].groupby("id").count(),
                 x="event_id", bins=30, kde=True)
plot.fig.suptitle("Distribution of the number of events per essay - Train dataset")

plot = sns.displot(df_test_logs[["id","event_id"]].groupby("id").count(),
                   x="event_id", bins=30, kde=True)
plot.fig.suptitle("Distribution of the number of events per essay - Test dataset")
# Out:
# The average of the number of events per essay in the train dataset is : 1701.0
# The average of the number of events per essay in the test dataset is : 2.0
# Text(0.5, 0.98, 'Distribution of the number of events per essay - Test dataset')

# %%
df_event_count = df_train_logs['up_event'].value_counts().to_frame().reset_index().sort_values(by='up_event',ascending=[False])
df_event_count.columns = ['up_event', 'count']
df_event_count
# Out:
#        up_event    count
# 0             q  5364789
# 1         Space  1207128
# 2     Backspace   964089
# 3         Shift   334227
# 4    ArrowRight   121338
# ..          ...      ...
# 117          F1        1
# 116           k        1
# 115       Pause        1
# 114          Â´        1
# 129          F6        1
#
# [130 rows x 2 columns]

# %%
vocab_event = df_event_count["up_event"].values
vocab_event
# Out:
# array(['q', 'Space', 'Backspace', 'Shift', 'ArrowRight', 'Leftclick',
#        'ArrowLeft', '.', ',', 'ArrowDown', 'ArrowUp', 'Enter', 'CapsLock',
#        "'", 'Delete', 'Unidentified', 'Control', '"', '-', '?', ';', '=',
#        'Tab', '/', 'Rightclick', ':', '(', ')', '\\', 'ContextMenu',
#        'End', '!', 'Meta', 'Alt', 'c', '[', 'v', 'NumLock', 'Insert',
#        'Home', 'z', 'a', 'AudioVolumeDown', 'F2', 'x', 't',
#        'AudioVolumeUp', '$', 'i', '>', ']', 's', '*', '%', 'w', '&',
#        'Dead', 'm', 'Escape', 'ModeChange', 'F3', '<', 'AudioVolumeMute',
#        '+', 'o', 'F15', 'ScrollLock', 'PageDown', 'Process', 'h', 'b',
#        'e', 'p', '_', 'f', '{', 'PageUp', '`', 'r', '#', '0', '1',
#        'Middleclick', 'F12', '5', '\x97', 'OS', '@', 'n', 'y', 'g', 'F11',
#        'Ä±', 'MediaTrackNext', 'l', 'Clear', 'MediaPlayPause', 'd', 'V',
#        'j', 'u', 'â\x80\x93', '}', '~', 'AltGraph', '2', '|',
#        'Unknownclick', 'A', 'MediaTrackPrevious', '^', '\x96', '¿', '¡',
#        'M', 'S', 'T', 'Cancel', 'Ë\x86', 'F10', '\x80', 'C', 'Å\x9f',
#        '\x9b', 'ä', 'F1', 'k', 'Pause', 'Â´', 'F6'], dtype=object)

# %% [markdown]
# # Preprocessing data

# %%
SEQ_LENGTH = 1700
df_train_prepared_logs = df_train_logs[['id','event_id', 'up_event']][df_train_logs['event_id'] < SEQ_LENGTH]

df_train_prepared_logs = pd.pivot_table(data= df_train_prepared_logs, index='id', columns='event_id', values='up_event', fill_value='', aggfunc='first')
df_train_prepared_logs
# Out:
# event_id       1          2          3      4      5      6      7      8     \
# id
# 001519c8  Leftclick  Leftclick      Shift      q      q      q      q      q
# 0022f953  Leftclick      Shift          q      q      q      q  Space      q
# 0042269b  Leftclick      Shift          q      q      q      q      q      q
# 0059420b  Leftclick  Leftclick      Shift  Shift  Shift  Shift  Shift  Shift
# 0075873a  Leftclick      Shift          q      q      q      q      q      q
# ...             ...        ...        ...    ...    ...    ...    ...    ...
# ffb8c745  Leftclick        Tab  Leftclick  Space  Space  Space  Space  Space
# ffbef7e5  Leftclick  Leftclick      Shift      q      q      q      q  Space
# ffccd6fd  Leftclick  Leftclick          q      q      q      q      q      q
# ffec5b38  Leftclick      Shift          q      q      q      q      q      q
# fff05981  Leftclick  Leftclick          q      q  Space      q      q      q
#
# event_id   9      10    ...       1690       1691       1692       1693  \
# id                      ...
# 001519c8      q  Space  ...          q          q          q          q
# 0022f953      q  Space  ...      Shift          q          q          q
# 0042269b      q  Space  ...          q          q          q          q
# 0059420b  Shift  Shift  ...
# 0075873a      q      q  ...      Space          q          q          q
# ...         ...    ...  ...        ...        ...        ...        ...
# ffb8c745  Shift      q  ...  Backspace  Backspace  Backspace  Backspace
# ffbef7e5      q      q  ...          q          q          q          q
# ffccd6fd  Space      q  ...      Space      Space      Space      Space
# ffec5b38      q      q  ...          q          q          q          q
# fff05981      q  Space  ...  ArrowLeft      Space          q          q
#
# event_id       1694       1695       1696   1697   1698   1699
# id
# 001519c8          q      Space  Backspace      .  Space  Space
# 0022f953          q          q          q  Space      q      q
# 0042269b          q          q          q  Space      q      q
# 0059420b
# 0075873a      Space          q          q      q      q      q
# ...             ...        ...        ...    ...    ...    ...
# ffb8c745  Backspace  Backspace  Backspace      q      q      q
# ffbef7e5          q          .      Space  Shift      q  Space
# ffccd6fd      Space      Space      Space  Space  Space  Space
# ffec5b38          q          q          .  Space  Shift  Shift
# fff05981          q      Space          q      q  Space      q
#
# [2471 rows x 1699 columns]

# %%
df_train_prepared_logs["text"] = ""
for i in range(1, 1700):
    df_train_prepared_logs["text"] = df_train_prepared_logs["text"] + " " + df_train_prepared_logs[i]

df_train_prepared_logs["text"] = df_train_prepared_logs["text"].apply(lambda x : x.strip())
df_train_prepared_logs
# Out:
# event_id          1          2          3      4      5      6      7      8  \
# id
# 001519c8  Leftclick  Leftclick      Shift      q      q      q      q      q
# 0022f953  Leftclick      Shift          q      q      q      q  Space      q
# 0042269b  Leftclick      Shift          q      q      q      q      q      q
# 0059420b  Leftclick  Leftclick      Shift  Shift  Shift  Shift  Shift  Shift
# 0075873a  Leftclick      Shift          q      q      q      q      q      q
# ...             ...        ...        ...    ...    ...    ...    ...    ...
# ffb8c745  Leftclick        Tab  Leftclick  Space  Space  Space  Space  Space
# ffbef7e5  Leftclick  Leftclick      Shift      q      q      q      q  Space
# ffccd6fd  Leftclick  Leftclick          q      q      q      q      q      q
# ffec5b38  Leftclick      Shift          q      q      q      q      q      q
# fff05981  Leftclick  Leftclick          q      q  Space      q      q      q
#
# event_id      9     10  ...       1691       1692       1693       1694  \
# id                      ...
# 001519c8      q  Space  ...          q          q          q          q
# 0022f953      q  Space  ...          q          q          q          q
# 0042269b      q  Space  ...          q          q          q          q
# 0059420b  Shift  Shift  ...
# 0075873a      q      q  ...          q          q          q      Space
# ...         ...    ...  ...        ...        ...        ...        ...
# ffb8c745  Shift      q  ...  Backspace  Backspace  Backspace  Backspace
# ffbef7e5      q      q  ...          q          q          q          q
# ffccd6fd  Space      q  ...      Space      Space      Space      Space
# ffec5b38      q      q  ...          q          q          q          q
# fff05981      q  Space  ...      Space          q          q          q
#
# event_id       1695       1696   1697   1698   1699  \
# id
# 001519c8      Space  Backspace      .  Space  Space
# 0022f953          q          q  Space      q      q
# 0042269b          q          q  Space      q      q
# 0059420b
# 0075873a          q          q      q      q      q
# ...             ...        ...    ...    ...    ...
# ffb8c745  Backspace  Backspace      q      q      q
# ffbef7e5          .      Space  Shift      q  Space
# ffccd6fd      Space      Space  Space  Space  Space
# ffec5b38          q          .  Space  Shift  Shift
# fff05981      Space          q      q  Space      q
#
# event_id                                               text
# id
# 001519c8  Leftclick Leftclick Shift q q q q q q Space q ...
# 0022f953  Leftclick Shift q q q q Space q q Space Shift ...
# 0042269b  Leftclick Shift q q q q q q q Space q q q Spac...
# 0059420b  Leftclick Leftclick Shift Shift Shift Shift Sh...
# 0075873a  Leftclick Shift q q q q q q q q q q q Space q ...
# ...                                                     ...
# ffb8c745  Leftclick Tab Leftclick Space Space Space Spac...
# ffbef7e5  Leftclick Leftclick Shift q q q q Space q q q ...
# ffccd6fd  Leftclick Leftclick q q q q q q Space q q q q ...
# ffec5b38  Leftclick Shift q q q q q q q q Backspace q q ...
# fff05981  Leftclick Leftclick q q Space q q q q Space q ...
#
# [2471 rows x 1700 columns]

# %%
vocab = vocab_event.tolist()
VOCAB_SIZE = len(vocab)

# After this layer, we have a tensor of shape (batch_size, max_len) containing vocab indices.
vectorize_layer = tf.keras.layers.TextVectorization(max_tokens = len(vocab) + 2,
                                 output_mode='int',
                                 standardize=None,
                                 split="whitespace",
                                 vocabulary=vocab,
                                 output_sequence_length=1700)

vectorize_layer.get_vocabulary()
# Out:
# ['',
#  '[UNK]',
#  'q',
#  'Space',
#  'Backspace',
#  'Shift',
#  'ArrowRight',
#  'Leftclick',
#  'ArrowLeft',
#  '.',
#  ',',
#  'ArrowDown',
#  'ArrowUp',
#  'Enter',
#  'CapsLock',
#  "'",
#  'Delete',
#  'Unidentified',
#  'Control',
#  '"',
#  '-',
#  '?',
#  ';',
#  '=',
#  'Tab',
#  '/',
#  'Rightclick',
#  ':',
#  '(',
#  ')',
#  '\\',
#  'ContextMenu',
#  'End',
#  '!',
#  'Meta',
#  'Alt',
#  'c',
#  '[',
#  'v',
#  'NumLock',
#  'Insert',
#  'Home',
#  'z',
#  'a',
#  'AudioVolumeDown',
#  'F2',
#  'x',
#  't',
#  'AudioVolumeUp',
#  '$',
#  'i',
#  '>',
#  ']',
#  's',
#  '*',
#  '%',
#  'w',
#  '&',
#  'Dead',
#  'm',
#  'Escape',
#  'ModeChange',
#  'F3',
#  '<',
#  'AudioVolumeMute',
#  '+',
#  'o',
#  'F15',
#  'ScrollLock',
#  'PageDown',
#  'Process',
#  'h',
#  'b',
#  'e',
#  'p',
#  '_',
#  'f',
#  '{',
#  'PageUp',
#  '`',
#  'r',
#  '#',
#  '0',
#  '1',
#  'Middleclick',
#  'F12',
#  '5',
#  '\x97',
#  'OS',
#  '@',
#  'n',
#  'y',
#  'g',
#  'F11',
#  'Ä±',
#  'MediaTrackNext',
#  'l',
#  'Clear',
#  'MediaPlayPause',
#  'd',
#  'V',
#  'j',
#  'u',
#  'â\x80\x93',
#  '}',
#  '~',
#  'AltGraph',
#  '2',
#  '|',
#  'Unknownclick',
#  'A',
#  'MediaTrackPrevious',
#  '^',
#  '\x96',
#  '¿',
#  '¡',
#  'M',
#  'S',
#  'T',
#  'Cancel',
#  'Ë\x86',
#  'F10',
#  '\x80',
#  'C',
#  'Å\x9f',
#  '\x9b',
#  'ä',
#  'F1',
#  'k',
#  'Pause',
#  'Â´',
#  'F6']

# %%
# Create the x and y
X_train = vectorize_layer(df_train_prepared_logs["text"])

len_df_train = df_train_prepared_logs["text"].shape[0]
y_train = tf.reshape(tf.convert_to_tensor(df_train_scores["score"].values), (len_df_train, 1))

# %% [markdown]
# # Create the model

# %%
import tensorflow as tf
from tensorflow import keras


token_id_input = keras.Input(shape=(SEQ_LENGTH,), dtype=tf.int32)


outputs_tok_pos_emb = keras_nlp.layers.TokenAndPositionEmbedding(
    vocabulary_size=VOCAB_SIZE,
    sequence_length=SEQ_LENGTH,
    embedding_dim=32,
)(token_id_input)

outputs_transf_enc1 = keras_nlp.layers.TransformerEncoder(num_heads=6,
                                                         intermediate_dim=128,
                                                         dropout=0.1)(outputs_tok_pos_emb)
outputs_transf_enc2 = keras_nlp.layers.TransformerEncoder(num_heads=6,
                                                         intermediate_dim=128,
                                                         dropout=0.1)(outputs_transf_enc1)
outputs_transf_enc3 = keras_nlp.layers.TransformerEncoder(num_heads=6,
                                                         intermediate_dim=128,
                                                         dropout=0.1)(outputs_transf_enc2)

outputs = keras.layers.Dense(1)(outputs_transf_enc3[:, 0, :])


model = keras.Model(
    inputs=token_id_input,
    outputs=outputs,
)

model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 1700)]            0
#
#  token_and_position_embeddi  (None, 1700, 32)          58560
#  ng_4 (TokenAndPositionEmbe
#  dding)
#
#  transformer_encoder_12 (Tr  (None, 1700, 32)          12442
#  ansformerEncoder)
#
#  transformer_encoder_13 (Tr  (None, 1700, 32)          12442
#  ansformerEncoder)
#
#  transformer_encoder_14 (Tr  (None, 1700, 32)          12442
#  ansformerEncoder)
#
#  tf.__operators__.getitem_4  (None, 32)                0
#   (SlicingOpLambda)
#
#  dense_4 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 95919 (374.68 KB)
# Trainable params: 95919 (374.68 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(
    loss=keras.losses.mean_squared_error,
    optimizer=keras.optimizers.AdamW(5e-4),
    metrics=['mean_squared_error'],
    jit_compile=True,
)

model.fit(
    batch_size=32,
    shuffle=True,
    x = X_train,
    y = y_train,
    epochs=80
)
# Out:
# Epoch 1/80
# 78/78 [==============================] - 112s 1s/step - loss: 1.1743 - mean_squared_error: 1.1743
# Epoch 2/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.8936 - mean_squared_error: 0.8936
# Epoch 3/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.8040 - mean_squared_error: 0.8040
# Epoch 4/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.7131 - mean_squared_error: 0.7131
# Epoch 5/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.5940 - mean_squared_error: 0.5940
# Epoch 6/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.5326 - mean_squared_error: 0.5326
# Epoch 7/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.4476 - mean_squared_error: 0.4476
# Epoch 8/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.3855 - mean_squared_error: 0.3855
# Epoch 9/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.3551 - mean_squared_error: 0.3551
# Epoch 10/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.2897 - mean_squared_error: 0.2897
# Epoch 11/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.2491 - mean_squared_error: 0.2491
# Epoch 12/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.2122 - mean_squared_error: 0.2122
# Epoch 13/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.1904 - mean_squared_error: 0.1904
# Epoch 14/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.1734 - mean_squared_error: 0.1734
# Epoch 15/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.1658 - mean_squared_error: 0.1658
# Epoch 16/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.1475 - mean_squared_error: 0.1475
# Epoch 17/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.1465 - mean_squared_error: 0.1465
# Epoch 18/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.1285 - mean_squared_error: 0.1285
# Epoch 19/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.1180 - mean_squared_error: 0.1180
# Epoch 20/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.1170 - mean_squared_error: 0.1170
# Epoch 21/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.1240 - mean_squared_error: 0.1240
# Epoch 22/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.1124 - mean_squared_error: 0.1124
# Epoch 23/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.1096 - mean_squared_error: 0.1096
# Epoch 24/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.1153 - mean_squared_error: 0.1153
# Epoch 25/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.0970 - mean_squared_error: 0.0970
# Epoch 26/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.0916 - mean_squared_error: 0.0916
# Epoch 27/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0890 - mean_squared_error: 0.0890
# Epoch 28/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.0872 - mean_squared_error: 0.0872
# Epoch 29/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0831 - mean_squared_error: 0.0831
# Epoch 30/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.0850 - mean_squared_error: 0.0850
# Epoch 31/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0746 - mean_squared_error: 0.0746
# Epoch 32/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.0752 - mean_squared_error: 0.0752
# Epoch 33/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.0713 - mean_squared_error: 0.0713
# Epoch 34/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0679 - mean_squared_error: 0.0679
# Epoch 35/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.0653 - mean_squared_error: 0.0653
# Epoch 36/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.0583 - mean_squared_error: 0.0583
# Epoch 37/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.0634 - mean_squared_error: 0.0634
# Epoch 38/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.0669 - mean_squared_error: 0.0669
# Epoch 39/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0610 - mean_squared_error: 0.0610
# Epoch 40/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.0559 - mean_squared_error: 0.0559
# Epoch 41/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.0589 - mean_squared_error: 0.0589
# Epoch 42/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.0491 - mean_squared_error: 0.0491
# Epoch 43/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.0503 - mean_squared_error: 0.0503
# Epoch 44/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.0510 - mean_squared_error: 0.0510
# Epoch 45/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.0509 - mean_squared_error: 0.0509
# Epoch 46/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.0450 - mean_squared_error: 0.0450
# Epoch 47/80
# 78/78 [==============================] - 86s 1s/step - loss: 0.0455 - mean_squared_error: 0.0455
# Epoch 48/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0483 - mean_squared_error: 0.0483
# Epoch 49/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0465 - mean_squared_error: 0.0465
# Epoch 50/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0461 - mean_squared_error: 0.0461
# Epoch 51/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0436 - mean_squared_error: 0.0436
# Epoch 52/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0405 - mean_squared_error: 0.0405
# Epoch 53/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0442 - mean_squared_error: 0.0442
# Epoch 54/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0388 - mean_squared_error: 0.0388
# Epoch 55/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0371 - mean_squared_error: 0.0371
# Epoch 56/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0364 - mean_squared_error: 0.0364
# Epoch 57/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0392 - mean_squared_error: 0.0392
# Epoch 58/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0389 - mean_squared_error: 0.0389
# Epoch 59/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0379 - mean_squared_error: 0.0379
# Epoch 60/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0390 - mean_squared_error: 0.0390
# Epoch 61/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0390 - mean_squared_error: 0.0390
# Epoch 62/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0400 - mean_squared_error: 0.0400
# Epoch 63/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0373 - mean_squared_error: 0.0373
# Epoch 64/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0370 - mean_squared_error: 0.0370
# Epoch 65/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0360 - mean_squared_error: 0.0360
# Epoch 66/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0341 - mean_squared_error: 0.0341
# Epoch 67/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0306 - mean_squared_error: 0.0306
# Epoch 68/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0335 - mean_squared_error: 0.0335
# Epoch 69/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0327 - mean_squared_error: 0.0327
# Epoch 70/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0363 - mean_squared_error: 0.0363
# Epoch 71/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0374 - mean_squared_error: 0.0374
# Epoch 72/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0304 - mean_squared_error: 0.0304
# Epoch 73/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0349 - mean_squared_error: 0.0349
# Epoch 74/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0315 - mean_squared_error: 0.0315
# Epoch 75/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0306 - mean_squared_error: 0.0306
# Epoch 76/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0291 - mean_squared_error: 0.0291
# Epoch 77/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0276 - mean_squared_error: 0.0276
# Epoch 78/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0276 - mean_squared_error: 0.0276
# Epoch 79/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0262 - mean_squared_error: 0.0262
# Epoch 80/80
# 78/78 [==============================] - 87s 1s/step - loss: 0.0257 - mean_squared_error: 0.0257

# %%
for tok, score, idx in zip(X_train, y_train, range(15)):
    print(score.numpy(), np.around(model.predict(tf.expand_dims(tok, axis=0))[0], decimals=1))
# Out:
# 1/1 [==============================] - 1s 1s/step
# [3.5] [3.7]
# 1/1 [==============================] - 0s 18ms/step
# [3.5] [3.4]
# 1/1 [==============================] - 0s 17ms/step
# [6.] [6.1]
# 1/1 [==============================] - 0s 20ms/step
# [2.] [2.2]
# 1/1 [==============================] - 0s 19ms/step
# [4.] [4.1]
# 1/1 [==============================] - 0s 18ms/step
# [2.] [2.1]
# 1/1 [==============================] - 0s 18ms/step
# [4.5] [4.6]
# 1/1 [==============================] - 0s 19ms/step
# [4.] [4.1]
# 1/1 [==============================] - 0s 19ms/step
# [3.5] [3.4]
# 1/1 [==============================] - 0s 19ms/step
# [4.5] [4.6]
# 1/1 [==============================] - 0s 21ms/step
# [4.5] [4.5]
# 1/1 [==============================] - 0s 20ms/step
# [2.5] [2.8]
# 1/1 [==============================] - 0s 18ms/step
# [4.5] [4.6]
# 1/1 [==============================] - 0s 20ms/step
# [3.5] [3.6]
# 1/1 [==============================] - 0s 18ms/step
# [2.5] [2.5]

# %%
# Distribution of predicted scores
plt.figure(figsize=(12, 6))
sns.histplot(model.predict(X_train), bins=20, kde=True)
plt.title('Distribution of Predicted Scores')
plt.xlabel('Predicted Scores')
plt.ylabel('Frequency')
plt.show()
# Out:
# 78/78 [==============================] - 17s 217ms/step

# %%
df_test_prepared_logs = pd.pivot_table(data= df_test_logs, index='id', columns='event_id', values='up_event', fill_value='', aggfunc='first')

df_test_prepared_logs["text"] = ""
for i in range(1, 3):
    df_test_prepared_logs["text"] = df_test_prepared_logs["text"] + " " + df_test_prepared_logs[i]

df_test_prepared_logs["text"] = df_test_prepared_logs["text"].apply(lambda x : x.strip())

test_token_ids = vectorize_layer(df_test_prepared_logs["text"])
test_token_ids
# Out:
# <tf.Tensor: shape=(3, 1700), dtype=int64, numpy=
# array([[3, 3, 0, ..., 0, 0, 0],
#        [2, 2, 0, ..., 0, 0, 0],
#        [3, 2, 0, ..., 0, 0, 0]])>

# %%
print(model.predict(test_token_ids))
# Out:
# 1/1 [==============================] - 1s 599ms/step
# [[0.5272884 ]
#  [0.4876543 ]
#  [0.52751744]]
